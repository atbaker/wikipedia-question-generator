# %%
import wikipedia
from textblob import TextBlob

# %%
page = wikipedia.page('Tony Bennett')

# %%
page.categories
# Out:
# ['1926 births',
#  '20th-century American painters',
#  '20th-century American singers',
#  '21st-century American painters',
#  '21st-century American singers',
#  'All articles with dead external links',
#  'American crooners',
#  'American jazz musicians',
#  'American jazz singers',
#  'American male singers',
#  'American military personnel of World War II',
#  'American people of Calabrian descent',
#  'American people of Italian descent',
#  'American pop singers',
#  'Articles with dead external links from April 2012',
#  'Articles with hCards',
#  'Artists from New York City',
#  'Columbia Records artists',
#  'Commons category with local link same as on Wikidata',
#  'Concord Records artists',
#  'Good articles',
#  'Grammy Award-winning artists',
#  'Grammy Lifetime Achievement Award winners',
#  'Kennedy Center honorees',
#  'Living people',
#  'Musicians from New York',
#  'New York Democrats',
#  'People from Astoria, Queens',
#  'Primetime Emmy Award winners',
# ...

# %%
page.summary
# Out:
# 'Anthony Dominick "Tony" Benedetto (born August 3, 1926), known as Tony Bennett, is an American singer of traditional pop standards, show tunes, and jazz. Bennett is also an accomplished painter, having created works—under the name Anthony Benedetto—that are on permanent public display in several institutions. He is the founder of the Frank Sinatra School of the Arts in Astoria, Queens, New York.\nBorn and raised in Astoria, Bennett began singing at an early age. He fought in the final stages of World War II as an infantryman with the U.S. Army in the European Theater. Afterwards, he developed his singing technique, signed with Columbia Records, and had his first number-one popular song with "Because of You" in 1951. Several top hits such as "Rags to Riches" followed in the early 1950s. Bennett then further refined his approach to encompass jazz singing. He reached an artistic peak in the late 1950s with albums such as The Beat of My Heart and Basie Swings, Bennett Sings. In 1962, Be
# ...

# %%
blob = TextBlob(page.summary)

# %%
blob.tags
# Out:
# [('Anthony', 'NNP'),
#  ('Dominick', 'NNP'),
#  ('Tony', 'NNP'),
#  ('Benedetto', 'NNP'),
#  ('born', 'VBN'),
#  ('August', 'NNP'),
#  ('3', 'CD'),
#  ('1926', 'CD'),
#  ('known', 'VBN'),
#  ('as', 'IN'),
#  ('Tony', 'NNP'),
#  ('Bennett', 'NNP'),
#  ('is', 'VBZ'),
#  ('an', 'DT'),
#  ('American', 'NNP'),
#  ('singer', 'NN'),
#  ('of', 'IN'),
#  ('traditional', 'JJ'),
#  ('pop', 'NN'),
#  ('standards', 'NNS'),
#  ('show', 'NN'),
#  ('tunes', 'NNS'),
#  ('and', 'CC'),
#  ('jazz', 'NN'),
#  ('Bennett', 'NNP'),
#  ('is', 'VBZ'),
#  ('also', 'RB'),
#  ('an', 'DT'),
#  ('accomplished', 'VBN'),
#  ('painter', 'NN'),
#  ('having', 'VBG'),
#  ('created', 'VBN'),
#  ('works—under', 'NN'),
#  ('the', 'DT'),
#  ('name', 'NN'),
#  ('Anthony', 'NNP'),
#  ('Benedetto—that', 'NN'),
#  ('are', 'VBP'),
#  ('on', 'IN'),
#  ('permanent', 'JJ'),
#  ('public', 'JJ'),
#  ('display', 'NN'),
#  ('in', 'IN'),
#  ('several', 'JJ'),
#  ('institutions', 'NNS'),
#  ('He', 'PRP'),
#  ('is', 'VBZ'),
# ...

# %%
blob.noun_phrases
# Out:
# WordList(['anthony dominick', 'tony', 'benedetto', 'august', 'tony bennett', 'american singer', 'show tunes', 'bennett', 'anthony benedetto—that', 'permanent public display', 'frank sinatra', 'astoria', 'queens', 'york', 'born', 'astoria', 'bennett', 'early age', 'final stages', 'world war', 'ii', 'u.s.', 'european theater', 'singing technique', 'columbia records', 'popular song', 'top hits', 'rags', 'riches', 'early 1950s', 'bennett', 'encompass jazz singing', 'artistic peak', 'late 1950s', 'heart', 'basie swings', 'bennett sings', 'bennett', 'signature song', 'left', 'heart', 'san francisco', 'personal life', 'rock music era', 'bennett', 'late 1980s', 'gold record albums', 'mtv generation', 'musical style', 'concert performer', 'bennett', 'grammy awards', 'lifetime', 'achievement award', 'emmy awards', 'nea jazz', 'kennedy', 'honoree', 'records worldwide'])

# %%
test_sentences = [
    "Bennett is also an accomplished painter, having created works that are on permanent public display in several institutions.",
    "He fought in the final stages of World War II as an infantryman with the U.S. Army in the European Theater.",
    "In 1962, Bennett recorded his signature song, \"I Left My Heart in San Francisco\"",
    "He worked as a copy boy and runner for the Associated Press in Manhattan and in several other low-skilled, low-paying jobs."
]

bad_sentences = [
    "He is the founder of the Frank Sinatra School of the Arts in Astoria, Queens, New York",
    "Born and raised in Astoria, Bennett began singing at an early age.",
    "Afterwards, he developed his singing technique, signed with Columbia Records, and had his first number-one popular song with \"Because of You\" in 1951"
]

# %%
sentence_one = TextBlob(test_sentences[0])
sentence_one.tags
# Out:
# [('Bennett', 'NNP'),
#  ('is', 'VBZ'),
#  ('also', 'RB'),
#  ('an', 'DT'),
#  ('accomplished', 'VBN'),
#  ('painter', 'NN'),
#  ('having', 'VBG'),
#  ('created', 'VBN'),
#  ('works', 'NNS'),
#  ('that', 'IN'),
#  ('are', 'VBP'),
#  ('on', 'IN'),
#  ('permanent', 'JJ'),
#  ('public', 'JJ'),
#  ('display', 'NN'),
#  ('in', 'IN'),
#  ('several', 'JJ'),
#  ('institutions', 'NNS')]

# %%
sentence_two = TextBlob(test_sentences[1])
sentence_two.tags
# Out:
# [('He', 'PRP'),
#  ('fought', 'VBD'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('final', 'JJ'),
#  ('stages', 'NNS'),
#  ('of', 'IN'),
#  ('World', 'NNP'),
#  ('War', 'NNP'),
#  ('II', 'NNP'),
#  ('as', 'IN'),
#  ('an', 'DT'),
#  ('infantryman', 'NN'),
#  ('with', 'IN'),
#  ('the', 'DT'),
#  ('U.S.', 'NNP'),
#  ('Army', 'NNP'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('European', 'JJ'),
#  ('Theater', 'NNP')]

# %%
sentence_three = TextBlob(test_sentences[2])
print(sentence_three.tags)
print(sentence_three.noun_phrases)
'signature'
# Out:
# [('In', 'IN'), ('1962', 'CD'), ('Bennett', 'NNP'), ('recorded', 'VBN'), ('his', 'PRP$'), ('signature', 'NN'), ('song', 'NN'), ('I', 'PRP'), ('Left', 'NNP'), ('My', 'PRP$'), ('Heart', 'NNP'), ('in', 'IN'), ('San', 'NNP'), ('Francisco', 'NNP')]
# ['bennett', 'signature song', 'left', 'heart', 'san francisco']

# %%
sentence_four = TextBlob(test_sentences[3])
sentence_four.noun_phrases
# Out:
# WordList(['copy boy', 'manhattan'])

# %%
bad_one = TextBlob(bad_sentences[0])
bad_one.tags
# Out:
# [('He', 'PRP'),
#  ('is', 'VBZ'),
#  ('the', 'DT'),
#  ('founder', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('Frank', 'NNP'),
#  ('Sinatra', 'NNP'),
#  ('School', 'NNP'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('Arts', 'NNP'),
#  ('in', 'IN'),
#  ('Astoria', 'NNP'),
#  ('Queens', 'NNP'),
#  ('New', 'NNP'),
#  ('York', 'NNP')]

# %%
bad_two = TextBlob(bad_sentences[1])
bad_two.tags
# Out:
# [('Born', 'VBN'),
#  ('and', 'CC'),
#  ('raised', 'VBN'),
#  ('in', 'IN'),
#  ('Astoria', 'NNP'),
#  ('Bennett', 'NNP'),
#  ('began', 'VBD'),
#  ('singing', 'VBG'),
#  ('at', 'IN'),
#  ('an', 'DT'),
#  ('early', 'JJ'),
#  ('age', 'NN')]

# %%
bad_three = TextBlob(bad_sentences[2])
bad_three.tags
# Out:
# [('Afterwards', 'RB'),
#  ('he', 'PRP'),
#  ('developed', 'VBN'),
#  ('his', 'PRP$'),
#  ('singing', 'VBG'),
#  ('technique', 'NN'),
#  ('signed', 'VBD'),
#  ('with', 'IN'),
#  ('Columbia', 'NNP'),
#  ('Records', 'NNPS'),
#  ('and', 'CC'),
#  ('had', 'VBD'),
#  ('his', 'PRP$'),
#  ('first', 'JJ'),
#  ('number-one', 'JJ'),
#  ('popular', 'JJ'),
#  ('song', 'NN'),
#  ('with', 'IN'),
#  ('Because', 'IN'),
#  ('of', 'IN'),
#  ('You', 'PRP'),
#  ('in', 'IN'),
#  ('1951', 'CD')]

# %%
def first_attempt(blob):
    replace_nouns = []
    for counter, tag in enumerate(blob.tags):
        if tag[1] == 'NN':
            replace_nouns.append(tag[0])
            
            if len(blob.tags) < counter:
                next_tag = blob.tags[counter+1]
                if next_tag[1] == 'NN':
                    replace_nouns.append(next_tag[0])
            break
    
    for word in replace_nouns:
        blob = blob.replace(word, '__________')
    return blob

print('GOOD SENTENCES')
for sentence in test_sentences:
    print(first_attempt(TextBlob(sentence)))

print('BAD SENTENCES')
for sentence in bad_sentences:
    print(first_attempt(TextBlob(sentence)))
# Out:
# GOOD SENTENCES
# Bennett is also an accomplished __________, having created works that are on permanent public display in several institutions.
# He fought in the final stages of World War II as an __________ with the U.S. Army in the European Theater.
# In 1962, Bennett recorded his __________ song, "I Left My Heart in San Francisco"
# He worked as a __________ boy and runner for the Associated Press in Manhattan and in several other low-skilled, low-paying jobs.
# BAD SENTENCES
# He is the __________ of the Frank Sinatra School of the Arts in Astoria, Queens, New York
# Born and raised in Astoria, Bennett began singing at an early __________.
# Afterwards, he developed his singing __________, signed with Columbia Records, and had his first number-one popular song with "Because of You" in 1951

# %%
print('SECOND ATTEMPT')
# Out:
# SECOND ATTEMPT

# %%
body = TextBlob(page.summary)
body.sentences[:15]
# Out:
# [Sentence("Anthony Dominick "Tony" Benedetto (born August 3, 1926), known as Tony Bennett, is an American singer of traditional pop standards, show tunes, and jazz."),
#  Sentence("Bennett is also an accomplished painter, having created works—under the name Anthony Benedetto—that are on permanent public display in several institutions."),
#  Sentence("He is the founder of the Frank Sinatra School of the Arts in Astoria, Queens, New York."),
#  Sentence("Born and raised in Astoria, Bennett began singing at an early age."),
#  Sentence("He fought in the final stages of World War II as an infantryman with the U.S. Army in the European Theater."),
#  Sentence("Afterwards, he developed his singing technique, signed with Columbia Records, and had his first number-one popular song with "Because of You" in 1951."),
#  Sentence("Several top hits such as "Rags to Riches" followed in the early 1950s."),
#  Sentence("Bennett then further refined his approach to encompass jazz singing."),
# ...

# %%
def is_unusual_word(word, blob):
    return blob.words.count(word) < 5

def evaluate_sentence(sentence):
    replace_nouns = []
    for counter, tag in enumerate(sentence.tags):
        if tag[1] == 'NN':
            noun = tag[0]
            
            # Is it unusual? If not, it probably won't make for good trivia
            if not is_unusual_word(noun, body):
                break
            
            # Is it in a noun phrase? If so, replace everything in that phrase
            for phrase in sentence.noun_phrases:
                if noun in phrase:
                    [replace_nouns.append(word) for word in phrase.split()]
                    break
                else:
                    replace_nouns.append(noun)
            break
    
    if len(replace_nouns) == 0:
        # This sentence sucks!
        return None

    for word in replace_nouns:
        sentence = sentence.replace(word, '__________')
    return sentence

trivia_sentences = []

for sentence in body.sentences[:50]:
    trivia_sentence = evaluate_sentence(sentence)
    if trivia_sentence is not None:
        trivia_sentences.append(str(trivia_sentence))

import pprint
pp = pprint.PrettyPrinter(indent=4)

pp.pprint(trivia_sentences)
# Out:
# [   'Anthony Dominick "Tony" Benedetto (born August 3, 1926), known as Tony '
#     'Bennett, is an American __________ of traditional pop standards, show '
#     'tunes, and jazz.',
#     'Bennett is also an accomplished __________, having created works—under '
#     'the name Anthony Benedetto—that are on permanent public display in '
#     'several institutions.',
#     'He is the __________ of the Frank Sinatra School of the Arts in '
#     'Astoria, Queens, New York.',
#     'Born and raised in Astoria, Bennett began singing at an __________ '
#     '__________.',
#     'He fought in the final stages of World War II as an __________ with the '
#     'U.S. Army in the European Theater.',
#     'Afterwards, he developed his __________ __________, signed with '
#     'Columbia Records, and had his first number-one popular song with '
#     '"Because of You" in 1951.',
#     'Bennett then further refined his __________ to encompass jazz singing.',
# ...
